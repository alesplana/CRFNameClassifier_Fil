# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/clean_x.csv', sep='|', header=0)
df.fillna('', inplace=True)
df['full_name'] = df['A'] + ' ' + df['B'] + ' ' + df['1']
df['last_name'] = df['1']
df['first_name'] = df['A']
df['middle_name'] = df['B']

# %%
df.head(10)
# Out:
#           0         1                     2                     A  \
# 0  20227007       QUE         ANGELA GIMENA                ANGELA
# 1      7008   QUERONA      NORLEY MAEKA YAN          NORLEY MAEKA
# 2      7009  QUERUBIN       MA TERESA BRAÑA             MA TERESA
# 3      7010  QUERUBIN       MARIBELLE RAZON             MARIBELLE
# 4      7011   QUEVEDO    RHEA JAINE LAGRAMA            RHEA JAINE
# 5      7012   QUEZADA       CRISTINA VERANO              CRISTINA
# 6      7013      QUIA       NONITA SANTIAGO                NONITA
# 7      7014   QUIAMCO  MARIA LORETH OLETRES  MARIA LORETH OLETRES
# 8      7015    QUIAÑO     SHARA MAE FOLLERO             SHARA MAE
# 9      7016   QUIBIAL   YVEZ DE LOS ANGELES                  YVEZ
#
#                 B  is_surname_in_list                      full_name  \
# 0          GIMENA                True              ANGELA GIMENA QUE
# 1             YAN                True       NORLEY MAEKA YAN QUERONA
# 2           BRAÑA                True       MA TERESA BRAÑA QUERUBIN
# 3           RAZON                True       MARIBELLE RAZON QUERUBIN
# 4         LAGRAMA                True     RHEA JAINE LAGRAMA QUEVEDO
# 5          VERANO                True        CRISTINA VERANO QUEZADA
# 6        SANTIAGO                True           NONITA SANTIAGO QUIA
# 7                               False  MARIA LORETH OLETRES  QUIAMCO
# 8         FOLLERO                True       SHARA MAE FOLLERO QUIAÑO
# 9  DE LOS ANGELES                True    YVEZ DE LOS ANGELES QUIBIAL
#
#   last_name            first_name     middle_name
# 0       QUE                ANGELA          GIMENA
# 1   QUERONA          NORLEY MAEKA             YAN
# 2  QUERUBIN             MA TERESA           BRAÑA
# 3  QUERUBIN             MARIBELLE           RAZON
# 4   QUEVEDO            RHEA JAINE         LAGRAMA
# 5   QUEZADA              CRISTINA          VERANO
# 6      QUIA                NONITA        SANTIAGO
# 7   QUIAMCO  MARIA LORETH OLETRES
# 8    QUIAÑO             SHARA MAE         FOLLERO
# 9   QUIBIAL                  YVEZ  DE LOS ANGELES

# %%
common_names = {}

for segment in ['middle', 'last']:
    common_names[segment] = df.loc[df[f'{segment}_name'].notnull() & (df[f'{segment}_name'] != '') & (df[f'{segment}_name'].str.split().str.len() == 1), f'{segment}_name'] \
    .groupby(df[f'{segment}_name']).size().sort_values(ascending=False).index[:100].tolist()

suffixes = {'JR', 'III', 'IV', 'V', 'VI', 'VII', 'VIII'}
word_count = df['first_name'].str.split().explode().value_counts().reset_index(name='Frequency').rename(columns={'index': 'Word'})
word_count.drop(word_count[word_count['Word'].isin(suffixes)].index, inplace=True)
common_names['first'] = word_count['Word'].head(100).tolist()

# %%
def process_name_bio(row):
    full_name = row['full_name'].split()
    tokens = full_name
    labels = []
    
    for name_segment in ['FIRST', 'MIDDLE', 'LAST']:
        segment_words = row[f'{name_segment.lower()}_name'].split()
        if len(segment_words) == 0:
            continue
        elif len(segment_words) == 1:
            labels.append(f'B-{name_segment}')
        else:
            labels.extend([f'B-{name_segment}'] + [f'I-{name_segment}'] * (len(segment_words) - 1))
    
    return {
        'full_name': row['full_name'],
        'tokens': tokens,
        'labels': labels
    }

# %%
data = df.apply(process_name_bio, axis=1).tolist()
data_df = pd.DataFrame(data)

# %%
data_df
# Out:
#                             full_name                             tokens  \
# 0                   ANGELA GIMENA QUE              [ANGELA, GIMENA, QUE]
# 1            NORLEY MAEKA YAN QUERONA      [NORLEY, MAEKA, YAN, QUERONA]
# 2            MA TERESA BRAÑA QUERUBIN      [MA, TERESA, BRAÑA, QUERUBIN]
# 3            MARIBELLE RAZON QUERUBIN       [MARIBELLE, RAZON, QUERUBIN]
# 4          RHEA JAINE LAGRAMA QUEVEDO    [RHEA, JAINE, LAGRAMA, QUEVEDO]
# ...                               ...                                ...
# 1183447  BRITTANNY AIKI MARI FUSILERO  [BRITTANNY, AIKI, MARI, FUSILERO]
# 1183448      DIANA ROSE IDOS FUSILERO      [DIANA, ROSE, IDOS, FUSILERO]
# 1183449        JMKELVIN MIRANDA FUSIN         [JMKELVIN, MIRANDA, FUSIN]
# 1183450        JUDY ANN SAGION FUSTER        [JUDY, ANN, SAGION, FUSTER]
# 1183451       JERAMAE CUEVAS  FUTALAN         [JERAMAE, CUEVAS, FUTALAN]
#
#                                        labels
# 0                 [B-FIRST, B-MIDDLE, B-LAST]
# 1        [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 2        [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 3                 [B-FIRST, B-MIDDLE, B-LAST]
# 4        [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# ...                                       ...
# 1183447  [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 1183448  [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 1183449           [B-FIRST, B-MIDDLE, B-LAST]
# 1183450  [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 1183451            [B-FIRST, I-FIRST, B-LAST]
#
# [1183452 rows x 3 columns]

# %%
suffixes = {'JR', 'SR', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII'}
surname_indicators = {'DE', 'DEL', 'DELA', 'DELOS', 'SAN', 'SANTA', 'SANTO'}

def extract_features(tokens, index, common_first_names, common_last_names):
    word = tokens[index]
    features = {
        'word': word,
        'word.length': len(word),
        'word.is_first': index == 0,
        'word.is_last': index == len(tokens) - 1,
        'word.position': index,
        'word.relative_position': index / len(tokens),
        'word.is_suffix': word in suffixes,
        'word.is_surname_indicator': word in surname_indicators,
        'word.in_common_first_names': word in common_first_names,
        'word.in_common_last_names': word in common_last_names,
        'word.contains_hyphen': '-' in word,
        'word.contains_period': '.' in word,
    }

    if index > 0:
        prev_word = tokens[index - 1]
        features.update({
            'prev_word': prev_word,
            'prev_word.is_suffix': prev_word in suffixes,
            'prev_word.is_surname_indicator': prev_word in surname_indicators,
        })
    else:
        features['BOS'] = True

    if index < len(tokens) - 1:
        next_word = tokens[index + 1]
        features.update({
            'next_word': next_word,
            'next_word.is_suffix': next_word in suffixes,
            'next_word.is_surname_indicator': next_word in surname_indicators,
        })
    else:
        features['EOS'] = True

    return features
    
data_df['features'] = data_df.apply(lambda row: [extract_features(row['tokens'], i, set(common_names['first']), set(common_names['last'])) for i in range(len(row['tokens']))], axis=1)

# %%
data_df
# Out:
#                             full_name                             tokens  \
# 0                   ANGELA GIMENA QUE              [ANGELA, GIMENA, QUE]
# 1            NORLEY MAEKA YAN QUERONA      [NORLEY, MAEKA, YAN, QUERONA]
# 2            MA TERESA BRAÑA QUERUBIN      [MA, TERESA, BRAÑA, QUERUBIN]
# 3            MARIBELLE RAZON QUERUBIN       [MARIBELLE, RAZON, QUERUBIN]
# 4          RHEA JAINE LAGRAMA QUEVEDO    [RHEA, JAINE, LAGRAMA, QUEVEDO]
# ...                               ...                                ...
# 1183447  BRITTANNY AIKI MARI FUSILERO  [BRITTANNY, AIKI, MARI, FUSILERO]
# 1183448      DIANA ROSE IDOS FUSILERO      [DIANA, ROSE, IDOS, FUSILERO]
# 1183449        JMKELVIN MIRANDA FUSIN         [JMKELVIN, MIRANDA, FUSIN]
# 1183450        JUDY ANN SAGION FUSTER        [JUDY, ANN, SAGION, FUSTER]
# 1183451       JERAMAE CUEVAS  FUTALAN         [JERAMAE, CUEVAS, FUTALAN]
#
#                                        labels  \
# 0                 [B-FIRST, B-MIDDLE, B-LAST]
# 1        [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 2        [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 3                 [B-FIRST, B-MIDDLE, B-LAST]
# 4        [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# ...                                       ...
# 1183447  [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 1183448  [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 1183449           [B-FIRST, B-MIDDLE, B-LAST]
# 1183450  [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 1183451            [B-FIRST, I-FIRST, B-LAST]
#
#                                                   features
# 0        [{'word': 'ANGELA', 'word.length': 6, 'word.is...
# 1        [{'word': 'NORLEY', 'word.length': 6, 'word.is...
# 2        [{'word': 'MA', 'word.length': 2, 'word.is_fir...
# 3        [{'word': 'MARIBELLE', 'word.length': 9, 'word...
# 4        [{'word': 'RHEA', 'word.length': 4, 'word.is_f...
# ...                                                    ...
# 1183447  [{'word': 'BRITTANNY', 'word.length': 9, 'word...
# 1183448  [{'word': 'DIANA', 'word.length': 5, 'word.is_...
# 1183449  [{'word': 'JMKELVIN', 'word.length': 8, 'word....
# 1183450  [{'word': 'JUDY', 'word.length': 4, 'word.is_f...
# 1183451  [{'word': 'JERAMAE', 'word.length': 7, 'word.i...
#
# [1183452 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(data_df, test_size=0.2, random_state=42)

# Prepare data for CRF
X_train = train_df['features'].tolist()
y_train = train_df['labels'].tolist()
X_test = test_df['features'].tolist()
y_test = test_df['labels'].tolist()

# Display sample
print(train_df.head())
print("\nSample X_train:")
print(X_train[0])
print("\nSample y_train:")
print(y_train[0])
# Out:
#                           full_name                            tokens  \
# 279258       CHAIRA DE GUIA LIWANAG       [CHAIRA, DE, GUIA, LIWANAG]
# 691845  BEULAH GRACE ARROYO DACANAY  [BEULAH, GRACE, ARROYO, DACANAY]
# 531360        CHRISTINE ALIN CABANG         [CHRISTINE, ALIN, CABANG]
# 169950    MICHELLE MARVIL AGCAMARAN     [MICHELLE, MARVIL, AGCAMARAN]
# 494038       SOPHIA CELMAR GALENDEZ        [SOPHIA, CELMAR, GALENDEZ]
#
#                                        labels  \
# 279258  [B-FIRST, B-MIDDLE, I-MIDDLE, B-LAST]
# 691845   [B-FIRST, I-FIRST, B-MIDDLE, B-LAST]
# 531360            [B-FIRST, B-MIDDLE, B-LAST]
# 169950            [B-FIRST, B-MIDDLE, B-LAST]
# 494038            [B-FIRST, B-MIDDLE, B-LAST]
#
#                                                  features
# 279258  [{'word': 'CHAIRA', 'word.length': 6, 'word.is...
# 691845  [{'word': 'BEULAH', 'word.length': 6, 'word.is...
# 531360  [{'word': 'CHRISTINE', 'word.length': 9, 'word...
# 169950  [{'word': 'MICHELLE', 'word.length': 8, 'word....
# 494038  [{'word': 'SOPHIA', 'word.length': 6, 'word.is...
#
# Sample X_train:
# [{'word': 'CHAIRA', 'word.length': 6, 'word.is_first': True, 'word.is_last': False, 'word.position': 0, 'word.relative_position': 0.0, 'word.is_suffix': False, 'word.is_surname_indicator': False, 'word.in_common_first_names': False, 'word.in_common_last_names': False, 'word.contains_hyphen': False, 'word.contains_period': False, 'BOS': True, 'next_word': 'DE', 'next_word.is_suffix': False, 'next_word.is_surname_indicator': True}, {'word': 'DE', 'word.length': 2, 'word.is_first': False, 'word.is_last': False, 'word.position': 1, 'word.relative_position': 0.25, 'word.is_suffix': False, 'word.is_surname_indicator': True, 'word.in_common_first_names': False, 'word.in_common_last_names': False, 'word.contains_hyphen': False, 'word.contains_period': False, 'prev_word': 'CHAIRA', 'prev_word.is_suffix': False, 'prev_word.is_surname_indicator': False, 'next_word': 'GUIA', 'next_word.is_suffix': False, 'next_word.is_surname_indicator': False}, {'word': 'GUIA', 'word.length': 4, 'word.is_first': False, 'word.is_last': False, 'word.position': 2, 'word.relative_position': 0.5, 'word.is_suffix': False, 'word.is_surname_indicator': False, 'word.in_common_first_names': False, 'word.in_common_last_names': False, 'word.contains_hyphen': False, 'word.contains_period': False, 'prev_word': 'DE', 'prev_word.is_suffix': False, 'prev_word.is_surname_indicator': True, 'next_word': 'LIWANAG', 'next_word.is_suffix': False, 'next_word.is_surname_indicator': False}, {'word': 'LIWANAG', 'word.length': 7, 'word.is_first': False, 'word.is_last': True, 'word.position': 3, 'word.relative_position': 0.75, 'word.is_suffix': False, 'word.is_surname_indicator': False, 'word.in_common_first_names': False, 'word.in_common_last_names': False, 'word.contains_hyphen': False, 'word.contains_period': False, 'prev_word': 'GUIA', 'prev_word.is_suffix': False, 'prev_word.is_surname_indicator': False, 'EOS': True}]
#
# Sample y_train:
# ['B-FIRST', 'B-MIDDLE', 'I-MIDDLE', 'B-LAST']

# %%
import sklearn_crfsuite
from sklearn_crfsuite import metrics
from sklearn.metrics import classification_report

# Initialize the CRF model
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)

# Train the model
crf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = crf.predict(X_test)

# Evaluate the model
print("CRF Model Performance:")
print(metrics.flat_classification_report(y_test, y_pred))

# Get feature importance
feature_importances = crf.state_features_
sorted_features = sorted(
    feature_importances.items(),
    key=lambda x: abs(x[1]),
    reverse=True
)

print("\nTop 10 most important features:")
for (feature, weight) in sorted_features[:10]:
    print(f"{feature}: {weight}")
# Out:
# CRF Model Performance:
#               precision    recall  f1-score   support
#
#      B-FIRST       1.00      1.00      1.00    236691
#       B-LAST       1.00      1.00      1.00    236691
#     B-MIDDLE       0.96      1.00      0.98    220981
#      I-FIRST       0.99      0.94      0.96    133215
#       I-LAST       1.00      0.99      0.99      7456
#     I-MIDDLE       0.99      0.99      0.99      6501
#
#     accuracy                           0.99    841535
#    macro avg       0.99      0.98      0.99    841535
# weighted avg       0.99      0.99      0.99    841535
#
#
# Top 10 most important features:
# ('word.is_last', 'B-MIDDLE'): -11.391395
# ('word.is_last', 'I-FIRST'): -11.062834
# ('word.is_last', 'I-MIDDLE'): -10.978739
# ('prev_word:STA', 'I-MIDDLE'): 10.158458
# ('prev_word:STO', 'I-MIDDLE'): 8.787141
# ('word:DC', 'I-FIRST'): 7.604971
# ('word:MAE', 'I-FIRST'): 6.923913
# ('word:DG', 'I-FIRST'): 6.857006
# ('word:DL', 'I-FIRST'): 6.783962
# ('word:PEARL', 'I-FIRST'): 6.772407
